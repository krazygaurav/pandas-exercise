# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep="\t")

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
removeDollar = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(removeDollar)

# %%
chipo[chipo['item_price']>10].item_price.count()
# Out:
# 1130

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
temp_chipo = chipo.drop_duplicates(['item_name'])
price_per_item = temp_chipo[['item_price', 'item_name']]
price_per_item.sort_values(by='item_price', ascending=False)
# Out:
#       item_price                              item_name
# 281        23.78                       Steak Salad Bowl
# 445        22.20                                   Bowl
# 4          16.98                           Chicken Bowl
# 1229       11.89                    Barbacoa Salad Bowl
# 1132       11.89                    Carnitas Salad Bowl
# 7          11.75                          Steak Burrito
# 39         11.75                          Barbacoa Bowl
# 168        11.75                  Barbacoa Crispy Tacos
# 186        11.25                      Veggie Salad Bowl
# 738        11.25                      Veggie Soft Tacos
# 57         11.25                         Veggie Burrito
# 62         11.25                            Veggie Bowl
# 250        10.98                          Chicken Salad
# 92          9.25                     Steak Crispy Tacos
# 237         9.25                    Carnitas Soft Tacos
# 554         9.25                  Carnitas Crispy Tacos
# ...

# %%
chipo[chipo['item_name'] == 'Steak Salad Bowl']
# Out:
#       order_id  quantity         item_name  \
# 281        123         2  Steak Salad Bowl
# 606        250         1  Steak Salad Bowl
# 607        250         1  Steak Salad Bowl
# 613        253         2  Steak Salad Bowl
# 749        309         1  Steak Salad Bowl
# 1159       478         1  Steak Salad Bowl
# 1311       534         1  Steak Salad Bowl
# 1505       612         1  Steak Salad Bowl
# 1571       637         1  Steak Salad Bowl
# 1590       644         1  Steak Salad Bowl
# 1816       734         1  Steak Salad Bowl
# 2401       953         1  Steak Salad Bowl
# 2439       969         1  Steak Salad Bowl
# 2600      1032         1  Steak Salad Bowl
# 2624      1042         1  Steak Salad Bowl
# 2740      1088         1  Steak Salad Bowl
# 2804      1114         1  Steak Salad Bowl
# 2957      1176         1  Steak Salad Bowl
# 3098      1235         1  Steak Salad Bowl
# 3120      1244         1  Steak Salad Bowl
# 3350      1343         1  Steak Salad Bowl
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values(by='item_name', ascending=True)
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# 3422      1373         1  6 Pack Soft Drink
# 553        230         1  6 Pack Soft Drink
# 1916       774         1  6 Pack Soft Drink
# 1922       776         1  6 Pack Soft Drink
# 1937       784         1  6 Pack Soft Drink
# 3836      1537         1  6 Pack Soft Drink
# 298        129         1  6 Pack Soft Drink
# 1976       798         1  6 Pack Soft Drink
# 1167       481         1  6 Pack Soft Drink
# 3875      1554         1  6 Pack Soft Drink
# 1124       465         1  6 Pack Soft Drink
# 3886      1558         1  6 Pack Soft Drink
# 2108       849         1  6 Pack Soft Drink
# 3010      1196         1  6 Pack Soft Drink
# 4535      1803         1  6 Pack Soft Drink
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.sort_values(by="item_price", ascending=False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %% [markdown]
# ### Step 8. How many times were a Veggie Salad Bowl ordered?

# %%
chipo[chipo['item_name'] == 'Veggie Salad Bowl'].count()
# Out:
# order_id              18
# quantity              18
# item_name             18
# choice_description    18
# item_price            18
# dtype: int64

# %% [markdown]
# ### Step 9. How many times people orderd more than one Canned Soda?

# %%
len(chipo[(chipo['quantity']>1) & (chipo['item_name'] == 'Canned Soda')])
# Out:
# 20
